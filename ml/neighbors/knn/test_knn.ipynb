# %% [markdown]
# # Import packages

# %%
# Create data
from sklearn.datasets import make_blobs

import numpy as np
from numpy import array
import matplotlib.pyplot as plt

# Thinh's implementation
from knn import KNN

# %%
KNN??
# Out:
# Init signature: KNN(n_neighbors: int = 5)
# Source:
# class KNN:
#     """
#     Class to create k-nearest neighbors model
#     """
#
#     @property
#     def n_sample_fit_(self) -> int:
#         """Number of samples in the fitted data"""
#         return self.fit_X.shape[0]
#
#     @property
#     def classes_(self) -> np.ndarray:
#         """Class labels known to the classifier"""
#         return np.unique(self.fit_y)
#
#     @property
#     def nclass_(self) -> int:
#         """Number of classes"""
#         return len(self.classes_)
#
#     def __init__(self, n_neighbors: int = 5):
#         self.n_neighbors = n_neighbors
#         self.rg__ = np.random.default_rng()
#
#     def fit(self, X: np.ndarray, y: np.ndarray):
#         """Save X and y to this instance
#         """
#         self.fit_X = X
#         self.fit_y = y
#
#     def predict(self, X: np.ndarray) -> np.ndarray:
#         """
#         Predict results using fitted knn
#         """
# ...

# %% [markdown]
# # Create train data (5 clusters)

# %%
X, y = make_blobs(
    centers=5,
    random_state=42
)
X.shape, y.shape
# Out:
# ((100, 2), (100,))

# %%
"Class labels: ", np.unique(y)
# Out:
# ('Class labels: ', array([0, 1, 2, 3, 4]))

# %%
plt.scatter(X[:, 0], X[:, 1])

# %% [markdown]
# # Fit model

# %%
clf = KNN(3)
clf.fit(X, y)

# %% [markdown]
# # Test data

# %%
#  Test data
nX = array([
    [-6.1, -2.1], 
    [-9.9, 7.6],
    [-1.5, 5.1],
    [3.9, 2.5],
    [3.0, 2.5]])


plt.scatter(X[:, 0], X[:, 1])
plt.scatter(nX[:, 0], nX[:, 1])

# %% [markdown]
# # Predict

# %%
clf.predict(nX)
# Out:
# array([2, 3, 0, 1, 4])
